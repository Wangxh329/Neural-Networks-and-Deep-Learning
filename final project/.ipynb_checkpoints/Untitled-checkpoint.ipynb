# %%
import numpy as np

X_test = np.load("project/X_test.npy")
y_test = np.load("project/y_test.npy")
person_train_valid = np.load("project/person_train_valid.npy")
X_train_valid = np.load("project/X_train_valid.npy")
y_train_valid = np.load("project/y_train_valid.npy")
person_test = np.load("project/person_test.npy")

# %%
person_train_valid[0]
a = y_train_valid[0:1]
a.shape
# Out:
# (1,)

# %%
for i in range(9):
    X_train_valid_cur = X_train_valid[np.where(person_train_valid == i)[0], :, :]
    y_train_valid_cur = y_train_valid[np.where(person_train_valid == i)[0]]
    X_test_cur = X_test[np.where(person_test == i)[0], :, :]
    y_test_cur = y_test[np.where(person_test == i)[0]]
    np.save("project/subjects/X_train_valid_sub%d.npy" % i, X_train_valid_cur)
    np.save("project/subjects/y_train_valid_sub%d.npy" % i, y_train_valid_cur)
    np.save("project/subjects/X_test_sub%d.npy" % i, X_test_cur)
    np.save("project/subjects/y_test_sub%d.npy" % i, y_test_cur)
# Out:
# 199
# 398
# 596
# 792
# 989
# 1187
# 1387
# 1583
# 1777
# 1778
# 1779
# 1780
# 1781
# 1782
# 1783
# 1784
# 1785
# 1786
# 1787
# 1788
# 1789
# 1790
# 1791
# 1792
# 1793
# 1794
# 1795
# 1796
# 1797
# 1798
# 1799
# 1800
# 1801
# 1802
# 1803
# 1804
# 1805
# 1806
# 1807
# 1808
# 1809
# 1810
# 1811
# 1812
# 1813
# 1814
# 1815
# 1816
# 1817
# 1818
# 1819
# 1820
# 1821
# 1822
# 1823
# 1824
# 1825
# 1826
# 1827
# 1828
# 1829
# 1830
# 1831
# 1832
# 1833
# 1834
# 1835
# 1836
# 1837
# 1838
# 1839
# 1840
# 1841
# 1842
# 1843
# 1844
# 1845
# 1846
# 1847
# 1848
# 1849
# 1850
# 1851
# 1852
# 1853
# 1854
# 1855
# 1856
# 1857
# 1858
# 1859
# 1860
# 1861
# 1862
# 1863
# 1864
# 1865
# 1866
# 1867
# 1868
# 1869
# 1870
# 1871
# 1872
# 1873
# 1874
# 1875
# 1876
# 1877
# 1878
# 1879
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# ...

# %%
X_train_valid = np.load("project/X_train_valid.npy")
X_train_valid.shape
# Out:
# (2115, 25, 1000)
